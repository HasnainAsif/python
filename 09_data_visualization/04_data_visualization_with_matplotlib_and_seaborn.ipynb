# %% [markdown]
# # **Data Visualization Guide**
#
# <h2 style="font-family: 'poppins'; font-weight: bold; color: Green;">👨‍💻Author: Dr. Muhammad Aamamr Tufail</h2>
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/AammarTufail)
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/muhammadaammartufail)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/dr-muhammad-aammar-tufail-02471213b/)
#
# [![YouTube](https://img.shields.io/badge/YouTube-Profile-red?style=for-the-badge&logo=youtube)](https://www.youtube.com/@codanics)
# [![Facebook](https://img.shields.io/badge/Facebook-Profile-blue?style=for-the-badge&logo=facebook)](https://www.facebook.com/aammar.tufail)
# [![TikTok](https://img.shields.io/badge/TikTok-Profile-black?style=for-the-badge&logo=tiktok)](https://www.tiktok.com/@draammar)
#
# [![Twitter/X](https://img.shields.io/badge/Twitter-Profile-blue?style=for-the-badge&logo=twitter)](https://twitter.com/aammar_tufail)
# [![Instagram](https://img.shields.io/badge/Instagram-Profile-blue?style=for-the-badge&logo=instagram)](https://www.instagram.com/aammartufail/)
# [![Email](https://img.shields.io/badge/Email-Contact%20Me-red?style=for-the-badge&logo=email)](mailto:aammar@codanics.com)

# %% [markdown]
# # What is Data Visualization?
#
# - Data visualization is the `graphical representation` of information and data.
# - By using visual elements like charts, graphs, and maps, data visualization tools provide an accessible way to see and understand trends, outliers, and patterns in data.
#
# ## Important Libraries for Data Visualization in Python
#
# - **Matplotlib**: Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# - **Seaborn**: Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# - **Plotly**: Plotly is a Python graphing library that makes interactive, publication-quality graphs online.
# - **Bokeh**: Bokeh is an interactive visualization library that targets modern web browsers for presentation.
# - **Altair**: Altair is a declarative statistical visualization library for Python, based on Vega and Vega-Lite.
# - **ggplot**: ggplot is a plotting system for Python based on R's ggplot2 and the Grammar of Graphics. It is built for making profressional looking, plots quickly with minimal code.
# - **Pygal**: Pygal is a Python SVG charts creator that takes the hassle out of creating charts for the web.
# - **Geoplotlib**: Geoplotlib is a toolbox for creating maps and plotting geographical data.
# - **Gleam**: Gleam is inspired by R's Shiny package. It allows users to turn analysis scripts into interactive web apps without needing to know web development.
# - **Missingno**: Missingno provides a small toolset of flexible and easy-to-use missing data visualizations and utilities that allows you to get a quick visual summary of the completeness (or lack thereof) of your dataset.
# - **Leather**: Leather is the Python charting library for those who need charts now and don’t care if they’re perfect.
# - **Wordcloud**: Wordcloud is a tool for making beautiful word clouds.
# - **Venn**: Venn is a Python library for creating area-proportional two- and three-way Venn diagrams.
#
#
# ## ***Grammer of Graphics for plotting in Python***
#
# - **Data**: The data to be visualized.
# - **Aesthetics**: The visual properties of the data points, such as position, size, shape, color, and transparency.
# - **Geometry**: The geometric shapes used to represent the data points, such as bars, lines, and points.
# - **Facets**: The arrangement of the data into subsets, such as rows, columns, or panels.
# - **Statistics**: The statistical transformations applied to the data, such as aggregations, smoothing, and modeling.
# - **Scales**: The mapping of data values to visual properties, such as axis limits, tick marks, and color scales.
# - **Themes**: The overall visual appearance of the plot, such as colors, fonts, and gridlines.
# - **Guides**: The visual elements used to assist in reading the plot, such as legends, axes, and labels.
# - **Interactivity**: The interactive features of the plot, such as tooltips, zooming, and panning.
# - **Annotations**: The textual and graphical annotations used to highlight specific aspects of the plot.
# - **Extensions**: The additional features and plugins that enhance the plot, such as animations, sliders, and widgets.
#
# ## **Parts of a plot**
#
# - **Title**: The title of the plot, which describes the main purpose or content of the visualization.
# - **Axis Labels**: The labels for the x and y axes, which describe the variables being plotted.
# - **Tick Marks**: The marks along the axes that indicate the scale or range of the data.
# - **Gridlines**: The lines that extend from the tick marks to assist in reading the plot.
# - **Legend**: The key that explains the colors, shapes, or sizes used to represent different groups or variables.
# - **Data Points**: The individual points, bars, lines, or other shapes that represent the data values.
# - **Data Labels**: The text or numbers that provide additional information about the data points.
# - **Annotations**: The additional text or shapes that highlight specific aspects of the plot.
# - **Background**: The overall appearance of the plot, including colors, fonts, and borders.

# %% [markdown]
# # Data Visualization with Matplotlib and Seaborn

# %% [markdown]
# ## Loading the Libraries and Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the sample diamonds data
df = pd.read_csv('../00_datasets/diamonds.csv')

# Display the first few rows of the dataset
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ## Explain each part of diamonds dataset:
#
# A data frame with 53,940 rows and 10 variables:
#
# - **carat**: Weight of the diamond (0.2--5.01)
# - **cut**: Quality of the cut (Fair, Good, Very Good, Premium, Ideal)
# - **color**: Diamond color, from D (best) to J (worst)
# - **clarity**: A measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# - **depth**: Total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
# - **table**: Width of top of diamond relative to widest point (43--95)
# - **price**: Price in US dollars ($326--$18,823)
# - **x**: Length in mm (0--10.74)
# - **y**: Width in mm (0--58.9)
# - **z**: Depth in mm (0--31.8)

# %% [markdown]
# ## Basic Plots using Matplotlib

# %%
plt.plot(df['carat'], df['price'])

# %%
# Line Plot
plt.plot(df['carat'], df['price'])
plt.title('Carat vs Price Line Plot')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# %%
# Scatter Plot
plt.scatter(df['carat'], df['price'])
plt.title('Carat vs Price Scatter Plot')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# %%
# Bar Plot
plt.bar(df['cut'].unique(), df.groupby('cut')['price'].mean())
plt.title('Average Price by Cut')
plt.xlabel('Cut')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# ## Intermediate Plots using Matplotlib

# %%
# Histogram
plt.hist(df['price'], bins=20, edgecolor='black')
plt.title('Distribution of Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Box Plot
plt.boxplot(df['carat'], vert=False) # horizontal box plot
plt.title('Box Plot of Carat')
plt.xlabel('Carat')
plt.show()

# %%
print(df['cut'].value_counts())
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
# Pie Chart
cut_counts = df['cut'].value_counts()
plt.pie(cut_counts, labels=cut_counts.index, autopct='%1.1f%%', startangle=90) # autopct shows the percentage on the pie chart
plt.title('Distribution of Cut Quality')
plt.show()

# %% [markdown]
# ## Advanced Plots using Matplotlib

# %%
correlation = df[['carat', 'depth', 'table', 'price', 'x', 'y', 'z']].corr() # corr measures the linear relationship between variables. --> if the correlation is close to 1 or -1, it indicates a strong positive or negative relationship. 0 means no relationship.
print("Correlation Matrix:")
print(correlation)
# Out:
# Correlation Matrix:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
# Heatmap of Correlation Matrix
correlation = df[['carat', 'depth', 'table', 'price', 'x', 'y', 'z']].corr()
plt.imshow(correlation, cmap='coolwarm', interpolation='none') # cmap specifies the color map, interpolation='none' means no interpolation between pixels
plt.colorbar()
plt.xticks(range(len(correlation)), correlation.columns, rotation=90)
plt.yticks(range(len(correlation)), correlation.columns)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
sns.heatmap(correlation, annot=True, cmap='coolwarm')

# plt.title('Seaborn Heatmap of Correlation Matrix')
# plt.xticks(rotation=45) # rotation of the x-axis labels
# Out:
# <Axes: >

# %% [markdown]
# ## Subplots

# %%
# Subplots

plt.rcParams.update(plt.rcParamsDefault) # reset settings of plt

fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True) # sharey=True means both subplots will share the same y-axis
axes[0].hist(df['carat'], bins=10, edgecolor='black')
axes[0].set_title('Histogram of Carat')
axes[1].hist(df['price'], bins=10, edgecolor='black')
axes[1].set_title('Histogram of Price')
plt.show()

# %%
# Subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes[0, 0].hist(df['carat'], bins=10, edgecolor='black')
axes[0, 0].set_title('Histogram of Carat')
axes[0, 1].hist(df['price'], bins=10, edgecolor='black')
axes[0, 1].set_title('Histogram of Price')
axes[1, 0].scatter(df['carat'], df['price'])
axes[1, 0].set_title('Carat vs Price Scatter Plot') 
axes[1, 0].set_xlabel('Carat')
axes[1, 0].set_ylabel('Price')
axes[1, 1].bar(df['cut'].unique(), df.groupby('cut')['price'].mean())
axes[1, 1].set_title('Average Price by Cut')
axes[1, 1].set_xlabel('Cut')
plt.show()

# %% [markdown]
# ## Basic Plots using Seaborn

# %%
# Seaborn Scatter Plot
sns.scatterplot(x='carat', y='price', data=df)
plt.title('Seaborn Scatter Plot of Carat vs Price')
plt.show()

# %%
# Seaborn Scatter Plot
sns.scatterplot(x='carat', y='price', data=df, hue='cut')
plt.title('Seaborn Scatter Plot of Carat vs Price')
plt.show()

# %%
# Seaborn Line Plot
sns.lineplot(x='carat', y='price', data=df)
plt.title('Seaborn Line Plot of Carat vs Price')
plt.show()

# %%
# Seaborn Line Plot
figure = plt.figure(figsize=(12, 3))
sns.lineplot(x='carat', y='price', data=df, hue='cut')
plt.title('Seaborn Line Plot of Carat vs Price')
plt.show()

# %%
# Seaborn Line Plot with Facets based on 'cut' column
g = sns.FacetGrid(df, col='cut', col_wrap=3, height=4)
g.map(sns.lineplot, 'carat', 'price')
g.add_legend()
plt.show()

# %% [markdown]
# ## Intermediate Plots using Seaborn

# %%
sns.boxplot(y='price', data=df)
# Out:
# <Axes: ylabel='price'>

# %%
# Box Plot
sns.boxplot(x='cut', y='price', data=df)
plt.title('Box Plot of Price by Cut')
plt.show()

# %%
figure = plt.figure(figsize=(12, 3))
# Box Plot
sns.boxplot(x='cut', y='price', data=df, hue='color')
plt.title('Box Plot of Price by Cut')
plt.show()

# %%
# Violin Plot
sns.violinplot(x='color', y='price', data=df)
plt.title('Violin Plot of Price by Color')
plt.show()

# %%
# Count Plot
sns.countplot(x='cut', data=df)
# sns.countplot(y='cut', data=df)
plt.title('Count Plot of Cut')
plt.show()

# %%
figure = plt.figure(figsize=(12, 3))
# Count Plot
sns.countplot(x='cut', data=df, hue='color') # adding subgroupd to the count plot using hue
plt.title('Count Plot of Cut')
plt.show()

# %% [markdown]
# ## Advanced Plots using Seaborn

# %%
# Heatmap
sns.heatmap(df[['carat', 'depth', 'table', 'price', 'x', 'y', 'z']].corr(), annot=True, cmap='coolwarm')
plt.title('Seaborn Heatmap of Correlation Matrix')
plt.show()

# %%
# the most time taking plot if the data is big
# Pair Plot
sns.pairplot(df, hue='cut')
plt.title('Pair Plot of Diamond Attributes')
plt.show()

# %%
# Facet Grid
g = sns.FacetGrid(df, col='color', col_wrap=3)
g.map(plt.hist, 'price', bins=10, edgecolor='black')
plt.show()

# %% [markdown]
# ## Enhancing Plots with Seaborn for Report-Ready Visualizations

# %% [markdown]
# ### Setting Seaborn Styles and Contexts

# %%
# Setting Seaborn style
sns.set_style('whitegrid') # For Background. Options: white, dark, whitegrid, darkgrid
sns.set_context('paper')  # For Font. Options: paper, notebook, talk, poster, or a dictionary with your parameters

# Example plot with updated style
sns.scatterplot(x='carat', y='price', data=df)
plt.title('Scatter Plot with Whitegrid Style and Paper Context')
plt.show()

# %%
# Using a dark background style
sns.set_style('dark')
sns.lineplot(x='carat', y='price', data=df)
plt.title('Line Plot with Dark Background Style')
plt.show()

# %%
# Customizing the font scale
sns.set_context('talk', font_scale=1.5)
sns.boxplot(x='cut', y='price', data=df)
plt.title('Box Plot with Talk Context and Larger Font Scale')
plt.show()

# %% [markdown]
# ### Customizing Color Palettes

# %%
# Using a predefined color palette
figure = plt.figure(figsize=(12, 3))
sns.set_context('notebook')
sns.set_palette('pastel') # Options: deep, muted, bright, pastel, dark, colorblind
sns.violinplot(x='color', y='price', data=df, hue='cut')
plt.title('Violin Plot with Pastel Color Palette')
plt.show()

# %%
# Creating and using a custom color palette
custom_palette = sns.color_palette(['#FF5733', '#33FFCE', '#335BFF', '#FF33A1', '#9B33FF', '#33FF57', '#FF8C33'])
sns.set_palette(custom_palette)
sns.countplot(x='cut', data=df, hue='color')
plt.title('Count Plot with Custom Color Palette')
plt.show()

# %% [markdown]
# ### Adjusting Plot Elements for Better Presentation

# %%
# Adding gridlines to the background
sns.set_style('whitegrid')
sns.scatterplot(x='carat', y='price', data=df)
plt.grid(True, linestyle='--', alpha=0.5)  # Adding dashed gridlines
plt.title('Scatter Plot with Gridlines')
plt.show()

# %%
# Removing spines from the plot for a cleaner look
sns.set_style('white')
ax = sns.histplot(df['price'], bins=10, edgecolor='black')
sns.despine()  # Remove the top and right spines
plt.title('Histogram with Spines Removed')
plt.show()

# %% [markdown]
# ### Adding Annotations and Legends

# %%
# Adding annotations to a scatter plot
sns.scatterplot(x='carat', y='price', data=df)
plt.title('Scatter Plot with Annotations')
for i in range(len(df)):
    plt.annotate(f"${df['price'][i]}", (df['carat'][i], df['price'][i]), fontsize=8, alpha=0.7)
plt.show()

# %%
# Customizing the legend
figure = plt.figure(figsize=(12, 3))
sns.set_style('white') # Set background style
sns.boxplot(x='cut', y='price', data=df)
plt.legend(title='Cut Types', labels=df['cut'].unique(), loc='lower right', frameon=True) # frameon adds a frame around the legend
plt.title('Box Plot with Custom Legend')
plt.show()

# %%
# Customizing the legend
figure = plt.figure(figsize=(12, 3))
sns.boxplot(x='cut', y='price', data=df)
plt.legend(title='Cut Types', labels=df['cut'].unique(), loc='upper left', bbox_to_anchor=(1, 1), frameon=True) # bbox_to_anchor allows you to position the legend outside the plot area
plt.title('Box Plot with Custom Legend')
plt.show()

# %% [markdown]
# ### Using FacetGrid for Multi-Panel Plots

# %%
# FacetGrid for multiple histograms based on cut
g = sns.FacetGrid(df, col='cut', col_wrap=3, height=4)
g.map(plt.hist, 'price', bins=10, edgecolor='black')
g.set_titles("{col_name} Cut") # Set titles for each subplot
g.set_axis_labels('Price', 'Frequency')
plt.show()

# %%
# fig = plt.figure(figsize=(12, 6))
# Using FacetGrid with scatter plots and hue
g = sns.FacetGrid(df, hue='color', height=5)
g.map(plt.scatter, 'carat', 'price').add_legend()
plt.title('FacetGrid Scatter Plot with Hue')
plt.show()

# %% [markdown]
# ### Fine-Tuning Axis Labels and Titles

# %%
# Rotating x-axis labels for better readability
sns.barplot(x='color', y='price', data=df) # Price is the average price for each color
plt.xticks(rotation=45)  # Rotate x-axis labels
plt.title('Bar Plot with Rotated X-axis Labels')
plt.show()

# %%
# Adjusting the y-axis scale
sns.histplot(df['price'], bins=10, edgecolor='black')
# plt.yscale('log')  # Use logarithmic scale for y-axis
plt.title('Histogram with Logarithmic Y-axis Scale')
plt.show()

# %%
# Adjusting the y-axis scale
sns.histplot(df['price'], bins=10, edgecolor='black') # count on y-axis represents the number of diamonds in each price range
plt.yscale('log')  # Use logarithmic scale for y-axis
plt.title('Histogram with Logarithmic Y-axis Scale')
plt.show()

# %% [markdown]
# ### Using Seaborn Themes for Final Touches

# %%
# Applying the 'ticks' theme
figure = plt.figure(figsize=(12, 3))
sns.set_theme(style='ticks', palette='muted', context='notebook', font_scale=1) 
# sns.set_style('ticks')  # Alternative way to set the ticks theme
# sns.set_palette('muted')  # Alternative way to set a muted color palette
# sns.set_context('notebook', font_scale=1)  # Alternative way to set context and font_scale for the plot
# # sns.set(font_scale=1)  # Alternative way to set font scale for better readability

sns.lineplot(x='carat', y='price', data=df)
sns.despine()  # Remove spines for a cleaner look
plt.title('Line Plot with Ticks Theme and Muted Palette')
plt.show()

# %%
# Using the 'darkgrid' theme for bar plots
sns.set_theme(style='darkgrid')
sns.barplot(x='cut', y='price', data=df)
plt.title('Bar Plot with Darkgrid Theme')
plt.show()

# %%
# Saving the refined plot to a file
sns.set_style('whitegrid')
sns.scatterplot(x='carat', y='price', data=df, hue='cut')
plt.title('Scatter Plot Ready for Reports')
plt.savefig('./02_plots/scatter_plot_report_png.png', dpi=300, bbox_inches='tight')
plt.savefig('./02_plots/scatter_plot_report_pdf.pdf', dpi=300, bbox_inches='tight') # pdf
plt.savefig('./02_plots/scatter_plot_report_svg.svg', dpi=300, bbox_inches='tight') # svg
plt.show()

# %%
import seaborn as sns

# List all color palettes available in Seaborn
palettes = sns.palettes.SEABORN_PALETTES
print(palettes)
# Out:
# {'deep': ['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD'], 'deep6': ['#4C72B0', '#55A868', '#C44E52', '#8172B3', '#CCB974', '#64B5CD'], 'muted': ['#4878D0', '#EE854A', '#6ACC64', '#D65F5F', '#956CB4', '#8C613C', '#DC7EC0', '#797979', '#D5BB67', '#82C6E2'], 'muted6': ['#4878D0', '#6ACC64', '#D65F5F', '#956CB4', '#D5BB67', '#82C6E2'], 'pastel': ['#A1C9F4', '#FFB482', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#DEBB9B', '#FAB0E4', '#CFCFCF', '#FFFEA3', '#B9F2F0'], 'pastel6': ['#A1C9F4', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#FFFEA3', '#B9F2F0'], 'bright': ['#023EFF', '#FF7C00', '#1AC938', '#E8000B', '#8B2BE2', '#9F4800', '#F14CC1', '#A3A3A3', '#FFC400', '#00D7FF'], 'bright6': ['#023EFF', '#1AC938', '#E8000B', '#8B2BE2', '#FFC400', '#00D7FF'], 'dark': ['#001C7F', '#B1400D', '#12711C', '#8C0800', '#591E71', '#592F0D', '#A23582', '#3C3C3C', '#B8850A', '#006374'], 'dark6': ['#001C7F', '#12711C', '#8C0800', '#591E71', '#B8850A', '#006374'], 'c
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to display all available Seaborn color palettes
def display_palettes():
    palette_names = sorted(sns.palettes.SEABORN_PALETTES)
    n = len(palette_names)
    
    # Create subplots
    fig, axes = plt.subplots(nrows=n, figsize=(8, 2 * n))
    
    for ax, palette_name in zip(axes, palette_names):
        colors = sns.color_palette(palette_name)
        for i, color in enumerate(colors):
            ax.add_patch(plt.Rectangle((i, 0), 1, 1, color=color))
        ax.set_xlim(0, len(colors))
        ax.set_ylim(0, 1)
        ax.set_title(palette_name, fontsize=10, pad=10)
        ax.axis('off')
    
    plt.tight_layout()
    plt.show()

display_palettes()
