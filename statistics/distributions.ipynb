# %% [markdown]
# # Normal Distribution of Probability distribution

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# load csv
amir_deals = pd.read_csv('../00_datasets/amir_deals.csv')
amir_deals.head()
# Out:
#    Unnamed: 0    product   client status   amount  num_users
# 0           1  Product F  Current    Won  7389.52         19
# 1           2  Product C      New    Won  4493.01         43
# 2           3  Product B      New    Won  5738.09         87
# 3           4  Product I  Current    Won  2591.24         83
# 4           5  Product E  Current    Won  6622.97         17

# %%
# Histogram of amount with 10 bins 
amir_deals['amount'].hist(bins=10)
plt.show()

# %%
# Probability of deal < 7500
prob_less_7500 = norm.cdf(7500, 5000, 2000) # 5000 is mean, 2000 is std deviation
print(prob_less_7500)

# Probability of deal > 1000
prob_greater_1000 = 1 - norm.cdf(1000, 5000, 2000)
print(prob_greater_1000)

# Probability of deal between 3000 and 7000
prob_3000_to_7000 = norm.cdf(7000, 5000, 2000) - norm.cdf(3000, 5000, 2000)
print(prob_3000_to_7000)

# Calculate amount that 25% of deals will be less than
pct_25 = norm.ppf(0.25, 5000, 2000)
print(pct_25)
# Out:
# 0.8943502263331446
# 0.9772498680518208
# 0.6826894921370859
# 3651.0204996078364

# %%
# Calculate new average amount, assuming a 20% increase
new_mean = 5000 + (0.2*5000)

# Calculate new standard deviation, assuming a 30% increase
new_sd = 2000 + (0.3*2000)

# Simulate 36 new sales, assuming normal distribution
new_sales = norm.rvs(new_mean, new_sd, size=36) # size is number of sales
print(new_sales)

# Create histogram and show
plt.hist(new_sales)
plt.show()
# Out:
# [ 6242.26031377  8845.35765283  1289.1346905  10828.0206407
#   6703.8106405   7059.21216252 11865.24615839  5156.15266289
#   1130.64180283  1652.80812985  8096.93845974  8003.22648658
#   7075.59612159  3004.56225145  3755.70854042  5348.15947537
#   5833.0152505   5997.15335261  3828.44396354  4867.95301903
#    532.51024815  7028.55742344  4076.22947571  5445.09302157
#   2107.03222166  8773.89264638  9873.82533027  6749.1340414
#   9661.29293523  9121.65289417  7721.51919875 10210.36445094
#   5997.6943235   9733.48165258 11461.20743247  8338.98727284]
